# %%
#importing libraries
#importing libraries
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
#converting rgb to hsv
image = mpimg.imread('car.jpg')
image_hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

# cv2.imshow('RGB image', image)
# cv2.imshow('HSV image', image_hsv)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
plt.imshow(image)

# %%
plt.imshow(image_hsv)

# %%
#obtaining hue channel
plt.imshow(image_hsv[:,:,0])
plt.title('Hue Channel')
# Out:
# Text(0.5, 1.0, 'Hue Channel')

# %%
#obtaining saturation channel
plt.imshow(image_hsv[:,:,1])
plt.title('Saturation Channel')
# Out:
# Text(0.5, 1.0, 'Saturation Channel')

# %%
#obtaining the Value Channel
plt.imshow(image_hsv[:,:,2])
plt.title('Saturation Channel')
# Out:
# Text(0.5, 1.0, 'Saturation Channel')
